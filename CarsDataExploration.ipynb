# %% [markdown]
# # Data Exploration Notebook
#
# This notebook provides a sketchpad for exploring the CSV cars dataset, to identify problematic columns and explore values in order to have an idea for the  construction of the ETL pipeline

# %%
! . ../venv/bin/activate
! pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.8/site-packages (3.6.2)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.8/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in ./venv/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in ./venv/lib/python3.8/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.8/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

df = pd.read_csv('beam_example/cars.csv')
df.head()
# Out:
#     make model  priceUSD  year     condition  mileage(kilometers) fuel_type  \
# 0  mazda     2      5500  2008  with mileage             162000.0    petrol
# 1  mazda     2      5350  2009  with mileage             120000.0    petrol
# 2  mazda     2      7000  2009  with mileage              61000.0    petrol
# 3  mazda     2      3300  2003  with mileage             265000.0    diesel
# 4  mazda     2      5200  2008  with mileage              97183.0    diesel
#
#    volume(cm3)     color transmission         drive_unit segment
# 0       1500.0  burgundy    mechanics  front-wheel drive       B
# 1       1300.0     black    mechanics  front-wheel drive       B
# 2       1500.0    silver         auto  front-wheel drive       B
# 3       1400.0     white    mechanics  front-wheel drive       B
# 4       1400.0      gray    mechanics  front-wheel drive       B

# %%
df.describe()
# Out:
#             priceUSD          year  mileage(kilometers)   volume(cm3)
# count   56244.000000  56244.000000         5.624400e+04  56197.000000
# mean     7415.456440   2003.454840         2.443956e+05   2104.860615
# std      8316.959261      8.144247         3.210307e+05    959.201633
# min        48.000000   1910.000000         0.000000e+00    500.000000
# 25%      2350.000000   1998.000000         1.370000e+05   1600.000000
# 50%      5350.000000   2004.000000         2.285000e+05   1996.000000
# 75%      9807.500000   2010.000000         3.100000e+05   2300.000000
# max    235235.000000   2019.000000         9.999999e+06  20000.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['priceUSD'], edgecolor='black', range=[1000, 120000])
# Out:
# (array([4.292e+04, 6.878e+03, 9.930e+02, 3.580e+02, 1.600e+02, 5.400e+01,
#         4.200e+01, 2.400e+01, 1.200e+01, 1.200e+01]),
#  array([  1000.,  12900.,  24800.,  36700.,  48600.,  60500.,  72400.,
#          84300.,  96200., 108100., 120000.]),
#  <BarContainer object of 10 artists>)

# %%
df[df['priceUSD']>100000]['priceUSD'].count()
# Out:
# 33

# %%
df.isnull().sum()
# Out:
# make                      0
# model                     0
# priceUSD                  0
# year                      0
# condition                 0
# mileage(kilometers)       0
# fuel_type                 0
# volume(cm3)              47
# color                     0
# transmission              0
# drive_unit             1905
# segment                5291
# dtype: int64

# %%
dupes_df = df[df.duplicated(keep=False)]
dupes_df[dupes_df['make'] == 'audi']
# Out:
#        make model  priceUSD  year     condition  mileage(kilometers)  \
# 1637   audi   100      1100  1989  with mileage             350000.0
# 1695   audi   100      1280  1991  with mileage             305000.0
# 1930   audi   100      1280  1991  with mileage             305000.0
# 2011   audi   100      2000  1988  with mileage             350000.0
# 2054   audi   100      2000  1988  with mileage             350000.0
# 2140   audi   100      1100  1989  with mileage             350000.0
# 11201  audi    a4      9500  2008  with mileage             185000.0
# 11314  audi    a4      6500  2003  with mileage             238000.0
# 11335  audi    a4      9500  2008  with mileage             185000.0
# 11564  audi    a4      6500  2003  with mileage             238000.0
# 11697  audi    a4      4700  2000  with mileage             300000.0
# 11712  audi    a4     10800  2009  with mileage             190000.0
# 11730  audi    a4     10800  2009  with mileage             190000.0
# 11803  audi    a4      4700  2000  with mileage             300000.0
# 11913  audi    a6      6650  2003  with mileage             357000.0
# 11982  audi    a6      8900  2008  with mileage             153000.0
# 12046  audi    a6      8900  2008  with mileage             153000.0
# 12146  audi    a6      8300  2005  with mileage             390000.0
# 12183  audi    a6      8300  2005  with mileage             390000.0
# 12184  audi    a6      6650  2003  with mileage             357000.0
# 12342  audi    a6      5400  2000  with mileage             350000.0
# 12833  audi    a6      5400  2000  with mileage             350000.0
# 13428  audi    a8      7000  2003  with mileage             350000.0
# 13440  audi    a8      7000  2003  with mileage             350000.0
# 41747  audi    q5     23500  2015  with mileage              57000.0
# 41810  audi    q5     23500  2015  with mileage              57000.0
#
#       fuel_type  volume(cm3)     color transmission  \
# 1637     petrol       2300.0  burgundy    mechanics
# 1695     petrol       2300.0       red    mechanics
# 1930     petrol       2300.0       red    mechanics
# 2011     petrol       2300.0      blue    mechanics
# 2054     petrol       2300.0      blue    mechanics
# 2140     petrol       2300.0  burgundy    mechanics
# 11201    petrol       1800.0      gray    mechanics
# 11314    diesel       2500.0      gray    mechanics
# 11335    petrol       1800.0      gray    mechanics
# 11564    diesel       2500.0      gray    mechanics
# 11697    diesel       1900.0     black    mechanics
# 11712    diesel       2000.0     black         auto
# 11730    diesel       2000.0     black         auto
# 11803    diesel       1900.0     black    mechanics
# 11913    diesel       1900.0    silver         auto
# 11982    petrol       2000.0     black         auto
# 12046    petrol       2000.0     black         auto
# 12146    diesel       2000.0     black    mechanics
# 12183    diesel       2000.0     black    mechanics
# 12184    diesel       1900.0    silver         auto
# 12342    diesel       1900.0      blue    mechanics
# 12833    diesel       1900.0      blue    mechanics
# 13428    petrol       4200.0     black         auto
# 13440    petrol       4200.0     black         auto
# 41747    petrol       2000.0      gray         auto
# 41810    petrol       2000.0      gray         auto
#
#                        drive_unit segment
# 1637            front-wheel drive       E
# 1695            front-wheel drive       E
# 1930            front-wheel drive       E
# 2011            front-wheel drive       E
# 2054            front-wheel drive       E
# 2140            front-wheel drive       E
# 11201           front-wheel drive       D
# 11314           front-wheel drive       D
# 11335           front-wheel drive       D
# 11564           front-wheel drive       D
# 11697           front-wheel drive       D
# 11712           front-wheel drive       D
# 11730           front-wheel drive       D
# 11803           front-wheel drive       D
# 11913           front-wheel drive       E
# 11982           front-wheel drive       E
# 12046           front-wheel drive       E
# 12146           front-wheel drive       E
# 12183           front-wheel drive       E
# 12184           front-wheel drive       E
# 12342           front-wheel drive       E
# 12833           front-wheel drive       E
# 13428             all-wheel drive       F
# 13440             all-wheel drive       F
# 41747  part-time four-wheel drive       J
# 41810  part-time four-wheel drive       J

# %%
df[df['volume(cm3)'].isna()]
# Out:
#              make          model  priceUSD  year     condition  \
# 2268   alfa-romeo            147      8097  2007  with mileage
# 4377      peugeot            406      5780  1995  with mileage
# 4865         fiat            500     14500  2014  with mileage
# 4867         fiat            500     13200  2013  with mileage
# 4868         fiat            500     14500  2015  with mileage
# 23577    cadillac            elr     25900  2014  with mileage
# 29346         bmw             i3     38000  2018  with mileage
# 29347         bmw             i3     57383  2017  with mileage
# 29350         bmw             i3     22900  2014  with mileage
# 29351         bmw             i3     22900  2015  with mileage
# 29463         bmw             i8     69082  2015  with mileage
# 32452      nissan           leaf     14500  2014  with mileage
# 32453      nissan           leaf     10950  2012  with mileage
# 32454      nissan           leaf     15400  2014  with mileage
# 32455      nissan           leaf     13950  2016  with mileage
# 32456      nissan           leaf      9300  2011  with mileage
# 32457      nissan           leaf     15649  2016  with mileage
# 32458      nissan           leaf     13350  2014  with mileage
# 32459      nissan           leaf     12850  2014  with mileage
# 32460      nissan           leaf     11900  2013  with mileage
# 32461      nissan           leaf     12900  2014  with mileage
# 32462      nissan           leaf     12950  2013  with mileage
# 32463      nissan           leaf     15500  2014  with mileage
# 32464      nissan           leaf     14366  2014  with mileage
# 32465      nissan           leaf     10000  2010  with mileage
# 32466      nissan           leaf     14000  2015  with mileage
# 34494       tesla        model-3     86353  2019  with mileage
# 34495       tesla        model-s     56000  2015  with mileage
# 34496       tesla        model-s     44000  2014  with mileage
# 34497       tesla        model-s    116994  2018  with mileage
# 34498       tesla        model-s     67900  2015  with mileage
# 34499       tesla        model-s     48000  2014  with mileage
# 34500       tesla        model-s     39999  2013  with mileage
# 34501       tesla        model-s     43950  2013  with mileage
# 34502       tesla        model-s     45000  2013  with mileage
# 34503       tesla        model-s     58500  2016  with mileage
# 34504       tesla        model-s     39900  2013  with mileage
# 34505       tesla        model-x     92500  2017  with mileage
# 34506       tesla        model-x     98000  2017  with mileage
# 34507       tesla        model-x    102509  2017  with mileage
# 34508       tesla        model-x    161563  2019  with mileage
# 34509       tesla        model-x     93000  2017  with mileage
# 38423  volkswagen         passat      9200  2011  with mileage
# 39014  volkswagen         passat      7499  2007  with mileage
# 42985  eksklyuziv  redkaya-model      2700  2001  with mileage
# 47711  eksklyuziv          sport      6500  2015  with mileage
# 52646   chevrolet           volt     22000  2015  with mileage
#
#        mileage(kilometers)   fuel_type  volume(cm3)     color transmission  \
# 2268                700.00  electrocar          NaN  burgundy    mechanics
# 4377             333333.00  electrocar          NaN    silver         auto
# 4865              49000.00  electrocar          NaN    orange         auto
# 4867              59900.00  electrocar          NaN      gray         auto
# 4868              30000.00  electrocar          NaN      gray         auto
# 23577             70000.00  electrocar          NaN    silver         auto
# 29346             67000.00  electrocar          NaN     other         auto
# 29347              2822.00  electrocar          NaN      blue         auto
# 29350             71500.00  electrocar          NaN    silver         auto
# 29351             50000.00  electrocar          NaN     black         auto
# 29463             38000.00  electrocar          NaN      gray         auto
# 32452             84000.00  electrocar          NaN     black         auto
# 32453             47400.00  electrocar          NaN     white         auto
# 32454             52125.00  electrocar          NaN       red         auto
# 32455             40000.00  electrocar          NaN     white         auto
# 32456             97000.00  electrocar          NaN      blue         auto
# 32457             15321.00  electrocar          NaN     other         auto
# 32458             52400.00  electrocar          NaN    silver         auto
# 32459             65900.00  electrocar          NaN      gray         auto
# 32460            193000.00  electrocar          NaN      blue         auto
# 32461             49000.00  electrocar          NaN     white         auto
# 32462             62000.00  electrocar          NaN     white         auto
# 32463             46000.00  electrocar          NaN      gray         auto
# 32464             73500.00  electrocar          NaN      blue         auto
# 32465             52000.00  electrocar          NaN  burgundy         auto
# 32466             54000.00  electrocar          NaN     white         auto
# 34494                50.00  electrocar          NaN       red         auto
# 34495             60000.00  electrocar          NaN      blue         auto
# 34496             62000.00  electrocar          NaN       red         auto
# 34497             49000.00  electrocar          NaN     black         auto
# 34498             52000.00  electrocar          NaN     white         auto
# 34499            128000.00  electrocar          NaN     white         auto
# 34500             33000.00  electrocar          NaN     black         auto
# 34501             73000.00  electrocar          NaN     green         auto
# 34502             99000.00  electrocar          NaN     black         auto
# 34503             29000.00  electrocar          NaN     white         auto
# 34504             34000.00  electrocar          NaN     green         auto
# 34505              8000.00  electrocar          NaN      blue         auto
# 34506             68000.00  electrocar          NaN      blue         auto
# 34507             38000.00  electrocar          NaN       red         auto
# 34508                50.00  electrocar          NaN     white         auto
# 34509             14000.00  electrocar          NaN       red         auto
# 38423            185000.00  electrocar          NaN    silver         auto
# 39014            530000.00  electrocar          NaN    silver    mechanics
# 42985               111.00  electrocar          NaN     green         auto
# 47711                10.00  electrocar          NaN     green         auto
# 52646            157715.32  electrocar          NaN    silver         auto
#
#                        drive_unit segment
# 2268                          NaN       C
# 4377            front-wheel drive       D
# 4865            front-wheel drive       M
# 4867            front-wheel drive       M
# 4868            front-wheel drive       M
# 23577           front-wheel drive     NaN
# 29346                  rear drive     NaN
# 29347                  rear drive     NaN
# 29350                  rear drive     NaN
# 29351                  rear drive     NaN
# 29463             all-wheel drive     NaN
# 32452           front-wheel drive     NaN
# 32453           front-wheel drive     NaN
# 32454           front-wheel drive     NaN
# 32455           front-wheel drive     NaN
# 32456           front-wheel drive     NaN
# 32457           front-wheel drive     NaN
# 32458           front-wheel drive     NaN
# 32459           front-wheel drive     NaN
# 32460           front-wheel drive     NaN
# 32461           front-wheel drive     NaN
# 32462           front-wheel drive     NaN
# 32463           front-wheel drive     NaN
# 32464           front-wheel drive     NaN
# 32465           front-wheel drive     NaN
# 32466           front-wheel drive     NaN
# 34494             all-wheel drive     NaN
# 34495             all-wheel drive     NaN
# 34496                  rear drive     NaN
# 34497             all-wheel drive     NaN
# 34498             all-wheel drive     NaN
# 34499                  rear drive     NaN
# 34500                  rear drive     NaN
# 34501           front-wheel drive     NaN
# 34502                  rear drive     NaN
# 34503             all-wheel drive     NaN
# 34504                  rear drive     NaN
# 34505             all-wheel drive     NaN
# 34506             all-wheel drive     NaN
# 34507  part-time four-wheel drive     NaN
# 34508  part-time four-wheel drive     NaN
# 34509             all-wheel drive     NaN
# 38423           front-wheel drive       D
# 39014           front-wheel drive       D
# 42985           front-wheel drive     NaN
# 47711                         NaN     NaN
# 52646           front-wheel drive     NaN

# %%
df['make'].unique()
# Out:
# array(['mazda', 'mg', 'renault', 'gaz', 'aro', 'rover', 'uaz',
#        'alfa-romeo', 'audi', 'oldsmobile', 'saab', 'peugeot', 'chrysler',
#        'wartburg', 'moskvich', 'volvo', 'fiat', 'roewe', 'porsche', 'zaz',
#        'luaz', 'dacia', 'lada-vaz', 'izh', 'raf', 'bogdan', 'bmw',
#        'nissan', 'mercedes-benz', 'mitsubishi', 'toyota', 'chery', 'gmc',
#        'hyundai', 'honda', 'ssangyong', 'suzuki', 'opel', 'seat',
#        'volkswagen', 'daihatsu', 'chevrolet', 'geely', 'saturn', 'kia',
#        'lincoln', 'eksklyuziv', 'citroen', 'dong-feng', 'pontiac', 'ford',
#        'subaru', 'bentley', 'faw', 'cadillac', 'lifan', 'plymouth',
#        'hafei', 'shanghai-maple', 'mini', 'jeep', 'skoda', 'mercury',
#        'changan', 'lexus', 'isuzu', 'aston-martin', 'lancia',
#        'great-wall', 'land-rover', 'jaguar', 'buick', 'daewoo', 'vortex',
#        'infiniti', 'byd', 'smart', 'maserati', 'haval', 'acura', 'scion',
#        'tata', 'datsun', 'tesla', 'mclaren', 'ravon', 'trabant', 'proton',
#        'fso', 'jac', 'asia', 'iran-khodro', 'zotye', 'tagaz', 'saipa',
#        'brilliance'], dtype=object)

# %%
with_drive_unit_df = df[~df['drive_unit'].isna()]
with_drive_unit_df['priceUSD'].describe()
plt.hist(with_drive_unit_df['priceUSD'], edgecolor='black', range=[7000, 78000])
# Out:
# (array([14817.,  4242.,  1202.,   464.,   259.,   164.,   106.,    49.,
#            34.,    18.]),
#  array([ 7000., 14100., 21200., 28300., 35400., 42500., 49600., 56700.,
#         63800., 70900., 78000.]),
#  <BarContainer object of 10 artists>)

# %%
df['color'].unique()
# Out:
# array(['burgundy', 'black', 'silver', 'white', 'gray', 'blue', 'other',
#        'purple', 'red', 'green', 'brown', 'yellow', 'orange'],
#       dtype=object)

# %%
df['drive_unit'].unique()
# Out:
# array(['front-wheel drive', nan, 'rear drive', 'all-wheel drive',
#        'part-time four-wheel drive'], dtype=object)
